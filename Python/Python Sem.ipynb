# %%
min = 645
hr = min//60
hr
# Out:
# 10

# %%
add = lambda a,b: (a+b)
avg = lambda a,b: add(a,b)/2
avg(2,3)
# Out:
# 2.5

# %%
import matplotlib.pyplot as plt
x=[10,20,30]
y=[5,2,7]
plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
y=[5,2,9,6,1]
plt.hist(y)
plt.show()
